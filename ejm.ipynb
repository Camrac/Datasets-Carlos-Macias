# %%
import pandas as pd 
import matplotlib.pyplot as plt 

tableAircraft=pd.read_csv('Aircraft_Incident_Dataset.csv')

# %%
tableAircraft.columns
# Out:
# Index(['Incident_Date', 'Aircaft_Model', 'Aircaft_Registration',
#        'Aircaft_Operator', 'Aircaft_Nature', 'Incident_Category',
#        'Incident_Cause(es)', 'Incident_Location', 'Aircaft_Damage_Type',
#        'Date', 'Time', 'Arit', 'Aircaft_Engines', 'Onboard_Crew',
#        'Onboard_Passengers', 'Onboard_Total', 'Fatalities',
#        'Aircaft_First_Flight', 'Aircraft_Phase', 'Departure_Airport',
#        'Destination_Airport', 'Ground_Casualties', 'Collision_Casualties'],
#       dtype='object')

# %%
tableAircraft[['Aircaft_Model','Aircaft_Operator','Incident_Category','Incident_Cause(es)','Incident_Location','Aircaft_Damage_Type','Aircraft_Phase','Fatalities','Aircaft_Registration']]
# Out:
#                              Aircaft_Model          Aircaft_Operator  \
# 0      British Aerospace 4121 Jetstream 41                SA Airlink
# 1      British Aerospace 3101 Jetstream 31                    LANHSA
# 2                           Boeing 737-4H6          Caspian Airlines
# 3                      Tupolev Tu-204-100C  Cainiao, opb Aviastar-TU
# 4            Beechcraft 200 Super King Air                   private
# ...                                    ...                       ...
# 23514                   Handley Page O/400    Handley Page Transport
# 23515                   Handley Page O/400    Handley Page Transport
# 23516                   Handley Page O/400    Handley Page Transport
# 23517                        Caproni Ca.48                   Caproni
# 23518                      Felixstowe Fury                       RAF
#
#                                        Incident_Category  \
# 0                           Accident | repairable-damage
# ...

# %%
tableAircraft['Aircaft_Model']
# Out:
# 0        British Aerospace 4121 Jetstream 41
# 1        British Aerospace 3101 Jetstream 31
# 2                             Boeing 737-4H6
# 3                        Tupolev Tu-204-100C
# 4              Beechcraft 200 Super King Air
#                         ...
# 23514                     Handley Page O/400
# 23515                     Handley Page O/400
# 23516                     Handley Page O/400
# 23517                          Caproni Ca.48
# 23518                        Felixstowe Fury
# Name: Aircaft_Model, Length: 23519, dtype: object

# %%
mascara = tableAircraft['Aircaft_Model'] ==  'British Aerospace 4121 Jetstream 41'

# %%
tableAircraft.loc[mascara,:]
# Out:
#      Incident_Date                        Aircaft_Model Aircaft_Registration  \
# 0      03-JAN-2022  British Aerospace 4121 Jetstream 41               ZS-NRJ
# 2551   24-SEP-2009  British Aerospace 4121 Jetstream 41               ZS-NRM
#
#      Aircaft_Operator                    Aircaft_Nature  \
# 0          SA Airlink  Domestic Non Scheduled Passenger
# 2551       SA Airlink                 Ferry/positioning
#
#                  Incident_Category  \
# 0     Accident | repairable-damage
# 2551          Accident | hull-loss
#
#                                      Incident_Cause(es)     Incident_Location  \
# 0     Airplane - Engines, Airplane - Engines - Prop/...  near Venetia Mine...
# 2551  Airplane - Engines, Airplane - Engines - Shutd...  near Durban Inter...
#
#         Aircaft_Damage_Type                        Date  ...  \
# 0               Substantial       Monday 3 January 2022  ...
# 2551  Damaged beyond repair  Thursday 24 September 2009  ...
#
# ...

# %%
a=tableAircraft.loc[:,'Aircaft_Model'] ==  'British Aerospace 4121 Jetstream 41'

# %%
a.sum
# Out:
# <bound method Series.sum of 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 23514    False
# 23515    False
# 23516    False
# 23517    False
# 23518    False
# Name: Aircaft_Model, Length: 23519, dtype: bool>

# %%
tableAircraft[mascara,:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:158, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 23514    False
# 23515    False
# 23516    False
# 23517    False
# 23518    False
# Name: Aircaft_Model, Length: 23519, dtype: bool, slice(None, None, None))' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# ...

# %%
mascara2 = tableAircraft['Aircaft_Model'] ==   'British Aerospace 3101 Jetstream 31'

# %%
tableAircraft.loc[mascara2,:]
# Out:
#      Incident_Date                        Aircaft_Model Aircaft_Registration  \
# 1      04-JAN-2022  British Aerospace 3101 Jetstream 31               HR-AYY
# 1595   12-OCT-2014  British Aerospace 3101 Jetstream 31                HI816
# 2023   31-DEC-2012  British Aerospace 3101 Jetstream 31               HR-AWG
# 3668   18-NOV-2004  British Aerospace 3101 Jetstream 31             YV-1083C
# 3712   17-JAN-2003  British Aerospace 3101 Jetstream 31              CP-2404
# 4343   30-NOV-2001  British Aerospace 3101 Jetstream 31               SE-LGA
# 6138   19-APR-1993  British Aerospace 3101 Jetstream 31               N131CA
# 6308   01-DEC-1993  British Aerospace 3101 Jetstream 31               N334PX
# 6402   12-MAR-1992  British Aerospace 3101 Jetstream 31               N165PC
# 6628   30-JAN-1991  British Aerospace 3101 Jetstream 31               N167PC
# 7370   26-DEC-1989  British Aerospace 3101 Jetstream 31               N410UE
# ...

# %%
mascara3 = tableAircraft['Aircaft_Model'] == 'Boeing 737-4H6'

# %%
tableAircraft.loc[mascara3,:]
# Out:
#      Incident_Date   Aircaft_Model Aircaft_Registration  Aircaft_Operator  \
# 2      05-JAN-2022  Boeing 737-4H6               EP-CAP  Caspian Airlines
# 1386   03-NOV-2015  Boeing 737-4H6               AP-BJO       Shaheen Air
# 1642   30-DEC-2014  Boeing 737-4H6               AP-BJN       Shaheen Air
# 1901   22-APR-2012  Boeing 737-4H6               AP-BJN       Shaheen Air
#
#                     Aircaft_Nature             Incident_Category  \
# 2     Domestic Scheduled Passenger  Accident | repairable-damage
# 1386  Domestic Scheduled Passenger          Accident | hull-loss
# 1642  Domestic Scheduled Passenger          Accident | hull-loss
# 1901  Domestic Scheduled Passenger  Accident | repairable-damage
#
#                                      Incident_Cause(es) Incident_Location  \
# 2     Airplane - Undercarriage, Airplane - Undercarr...   Isfahan-Shah...
# 1386  Airplane - Undercarriage, Flightcrew - Alcohol...   Lahore-Allam...
# ...

# %%
mascara4= tableAircraft['Aircaft_Model'] == 'Tupolev Tu-204-100C'

# %%
tableAircraft.loc[mascara4,:]
# Out:
#   Incident_Date        Aircaft_Model Aircaft_Registration  \
# 3   08-JAN-2022  Tupolev Tu-204-100C             RA-64032
#
#            Aircaft_Operator Aircaft_Nature     Incident_Category  \
# 3  Cainiao, opb Aviastar-TU          Cargo  Accident | hull-loss
#
#                                   Incident_Cause(es) Incident_Location  \
# 3  Cargo - Fire/smoke, Result - Damaged on the gr...   Hangzhou-Xia...
#
#   Aircaft_Damage_Type                     Date  ...  \
# 3           Destroyed  Saturday 8 January 2022  ...
#
#                    Onboard_Crew            Onboard_Passengers  \
# 3  Fatalities: 0 / Occupants: 8  Fatalities: 0 / Occupants: 0
#
#                   Onboard_Total Fatalities             Aircaft_First_Flight  \
# 3  Fatalities: 0 / Occupants: 8          0  2002-07-18  (19 years 6 months)
#
#    Aircraft_Phase                                  Departure_Airport  \
# 3  Standing (STD)  Hangzhou-Xiaoshan International Airport (HGH/Z...
#
# ...

# %%
mascara5= tableAircraft['Aircaft_Model'] == 'Beechcraft 200 Super King Air'

# %%
tableAircraft.loc[mascara5,:]
# Out:
#       Incident_Date                  Aircaft_Model Aircaft_Registration  \
# 4       12-JAN-2022  Beechcraft 200 Super King Air                  NaN
# 13      02-JAN-2021  Beechcraft 200 Super King Air               N831WP
# 37      21-FEB-2021  Beechcraft 200 Super King Air                  NaN
# 187     08-FEB-2020  Beechcraft 200 Super King Air               CC-COT
# 208     03-MAR-2020  Beechcraft 200 Super King Air               N186EB
# ...             ...                            ...                  ...
# 9617    27-OCT-1979  Beechcraft 200 Super King Air               XC-PGR
# 9852    03-OCT-1978  Beechcraft 200 Super King Air             YV-141CP
# 10016   18-APR-1977  Beechcraft 200 Super King Air               N256TM
# 10106   27-JUL-1977  Beechcraft 200 Super King Air               D-IBAF
# 10163   19-OCT-1977  Beechcraft 200 Super King Air               N17530
#
#                       Aircaft_Operator  Aircaft_Nature  \
# ...

# %%
mascara6= tableAircraft['Aircaft_Model'] == 'Handley Page O/400'

# %%
tableAircraft.loc[mascara6,:]
# Out:
#       Incident_Date       Aircaft_Model Aircaft_Registration  \
# 23514   25-FEB-1920  Handley Page O/400               G-EAMC
# 23515   30-JUN-1920  Handley Page O/400               G-EAKE
# 23516   14-DEC-1920  Handley Page O/400               G-EAMA
#
#              Aircaft_Operator                     Aircaft_Nature  \
# 23514  Handley Page Transport                            Unknown
# 23515  Handley Page Transport                      Demonstration
# 23516  Handley Page Transport  International Scheduled Passenger
#
#           Incident_Category  \
# 23514  Accident | hull-loss
# 23515  Accident | hull-loss
# 23516  Accident | hull-loss
#
#                                       Incident_Cause(es) Incident_Location  \
# 23514  Result - Emergency, forced landing - Outside a...   near El Shereik
# 23515  Result - Emergency, forced landing - Outside a...            Östanå
# 23516                       Result - CFIT - Level ground     Golders Green
#
# ...

# %%
mascara7= tableAircraft['Aircaft_Model'] == 'Caproni Ca.48'

# %%
tableAircraft.loc[mascara7,:]
# Out:
#       Incident_Date  Aircaft_Model Aircaft_Registration Aircaft_Operator  \
# 23517   02-AUG-1919  Caproni Ca.48                  NaN          Caproni
#
#       Aircaft_Nature     Incident_Category Incident_Cause(es)  \
# 23517      Passenger  Accident | hull-loss   Info-Unavailable
#
#       Incident_Location Aircaft_Damage_Type                    Date  ...  \
# 23517            Verona           Destroyed  Saturday 2 August 1919  ...
#
#                        Onboard_Crew              Onboard_Passengers  \
# 23517  Fatalities: 2 / Occupants: 2  Fatalities: 12 / Occupants: 12
#
#                         Onboard_Total Fatalities Aircaft_First_Flight  \
# 23517  Fatalities: 14 / Occupants: 14         14                 1919
#
#        Aircraft_Phase                             Departure_Airport  \
# 23517  En route (ENR)  Venice-Marco Polo Airport (VCE/LIPZ) , Italy
#
#                   Destination_Airport Ground_Casualties Collision_Casualties
# ...

# %%
mascara8= tableAircraft['Aircaft_Model'] == 'Felixstowe Fury'

# %%
tableAircraft.loc[mascara8,:]
# Out:
#       Incident_Date    Aircaft_Model Aircaft_Registration Aircaft_Operator  \
# 23518   11-AUG-1919  Felixstowe Fury                 N123              RAF
#
#       Aircaft_Nature     Incident_Category Incident_Cause(es)  \
# 23518           Test  Accident | hull-loss   Info-Unavailable
#
#          Incident_Location    Aircaft_Damage_Type                   Date  ...  \
# 23518  near Felixtowe RNAS  Damaged beyond repair  Monday 11 August 1919  ...
#
#                        Onboard_Crew            Onboard_Passengers  \
# 23518  Fatalities: 1 / Occupants: 7  Fatalities: 0 / Occupants: 0
#
#                       Onboard_Total Fatalities    Aircaft_First_Flight  \
# 23518  Fatalities: 1 / Occupants: 7          1  1918-11-11  (9 months)
#
#             Aircraft_Phase                 Departure_Airport  \
# 23518  Initial climb (ICL)  Felixstowe RNAS , United Kingdom
#
#                     Destination_Airport Ground_Casualties Collision_Casualties
# ...

# %%
tableAircraft.Aircaft_Model.hist(mascara)
# Out:
# array([<Axes: title={'center': 'False'}>,
#        <Axes: title={'center': 'True'}>], dtype=object)

# %%
tableAircraft.Aircaft_Model.hist(mascara2)
# Out:
# array([<Axes: title={'center': 'False'}>,
#        <Axes: title={'center': 'True'}>], dtype=object)

# %%
tableAircraft.Aircaft_Model.hist(mascara3)
# Out:
# array([<Axes: title={'center': 'False'}>,
#        <Axes: title={'center': 'True'}>], dtype=object)

# %%
tableAircraft.Aircaft_Model.value_counts()
# Out:
# Aircaft_Model
# Junkers Ju-52/3m                            466
# Douglas C-47-DL (DC-3)                      461
# Antonov An-2R                               379
# Douglas Dakota III (DC-3)                   261
# de Havilland Canada DHC-6 Twin Otter 300    253
#                                            ...
# Boeing EC-135J                                1
# Kawasaki P-3C-II.5 Orion                      1
# Douglas DC-8-33AF                             1
# Antonov An-30A                                1
# Felixstowe Fury                               1
# Name: count, Length: 3523, dtype: int64
